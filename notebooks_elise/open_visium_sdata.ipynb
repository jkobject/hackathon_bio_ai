# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from spatialdata import SpatialData
import pathlib

from napari_spatialdata import Interactive

plt.rcParams["figure.figsize"] = (20, 20)

FILE_PATH =pathlib.Path("/Users/lison/code/hackathon_bio_ai/example_data/saved_from_hest/INT1.zarr") # Change this
sdata = SpatialData.read(FILE_PATH)
# Out:
# /Users/lison/.pyenv/versions/3.9.13/envs/bio_ai_39/lib/python3.9/site-packages/numba/core/decorators.py:246: RuntimeWarning: nopython is set for njit and is ignored
#   warnings.warn('nopython is set for njit and is ignored', RuntimeWarning)

# %%
interactive = Interactive(sdata)

# %%
interactive

# %%
sdata
# Out:
# SpatialData object, with associated Zarr store: /Users/lison/code/hackathon_bio_ai/example_data/saved_from_hest/INT1.zarr
# ├── Images
# │     ├── 'ST_downscaled_hires_image': DataArray[cyx] (3, 2496, 2400)
# │     └── 'ST_downscaled_lowres_image': DataArray[cyx] (3, 1000, 962)
# ├── Shapes
# │     ├── 'cellvit': GeoDataFrame shape: (37483, 3) (2D shapes)
# │     ├── 'locations': GeoDataFrame shape: (1084, 2) (2D shapes)
# │     └── 'tissue_contours': GeoDataFrame shape: (2, 2) (2D shapes)
# └── Tables
#       └── 'table': AnnData (1084, 36601)
# with coordinate systems:
#     ▸ 'ST_downscaled_hires', with elements:
#         ST_downscaled_hires_image (Images), cellvit (Shapes), locations (Shapes), tissue_contours (Shapes)
#     ▸ 'ST_downscaled_lowres', with elements:
#         ST_downscaled_lowres_image (Images), cellvit (Shapes), locations (Shapes), tissue_contours (Shapes)

# %%
sdata.pl.render_shapes(color="SOX2").pl.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 sdata.pl.render_shapes(color="SOX2").pl.show()
#
# AttributeError: 'SpatialData' object has no attribute 'pl'

# %%
interactive.add_element(element='table', element_coordinate_system="Tables")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 interactive.add_element(element='table', element_coordinate_system="Tables")
#
# File ~/.pyenv/versions/3.9.13/envs/bio_ai_39/lib/python3.9/site-packages/napari_spatialdata/_interactive.py:71, in Interactive.add_element(self, element, element_coordinate_system, view_element_system)
#      69         self._viewer.layers[-1].visible = True
#      70 else:
# ---> 71     raise ValueError(f"Element {element} not found in coordinate system {element_coordinate_system}.")
#
# ValueError: Element table not found in coordinate system Tables.

# %%
interactive = Interactive(sdata)
interactive.run()

# %%
interactive.run()

# %%
plt.imshow(interactive.screenshot())
plt.axis("off")
# Out:
# (-0.5, 1705.5, 1737.5, -0.5)
# /Users/lison/.pyenv/versions/3.9.13/envs/bio_ai_39/lib/python3.9/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# 2024-12-06 13:57:20.970 | INFO     | napari_spatialdata._view:_on_layer_update:355 - Updating layer.
# 2024-12-06 13:57:20.972 | INFO     | napari_spatialdata._view:_on_layer_update:355 - Updating layer.

# %%
sdata
# Out:
# SpatialData object, with associated Zarr store: /Users/lison/code/hackathon_bio_ai/example_data/saved_from_hest/INT1.zarr
# ├── Images
# │     ├── 'ST_downscaled_hires_image': DataArray[cyx] (3, 2496, 2400)
# │     └── 'ST_downscaled_lowres_image': DataArray[cyx] (3, 1000, 962)
# ├── Shapes
# │     ├── 'cellvit': GeoDataFrame shape: (37483, 3) (2D shapes)
# │     ├── 'locations': GeoDataFrame shape: (1084, 2) (2D shapes)
# │     └── 'tissue_contours': GeoDataFrame shape: (2, 2) (2D shapes)
# └── Tables
#       └── 'table': AnnData (1084, 36601)
# with coordinate systems:
#     ▸ 'ST_downscaled_hires', with elements:
#         ST_downscaled_hires_image (Images), cellvit (Shapes), locations (Shapes), tissue_contours (Shapes)
#     ▸ 'ST_downscaled_lowres', with elements:
#         ST_downscaled_lowres_image (Images), cellvit (Shapes), locations (Shapes), tissue_contours (Shapes)

# %%
sdata.table
# Out:
# /var/folders/pq/0850dqgs4rjcbcqwl113v_sh0000gn/T/ipykernel_61312/4181403938.py:1: DeprecationWarning: Table accessor will be deprecated with SpatialData version 0.1, use sdata.tables instead.
#   sdata.table
# AnnData object with n_obs × n_vars = 1084 × 36601
#     obs: 'in_tissue', 'array_row', 'array_col', 'pxl_row_in_fullres', 'pxl_col_in_fullres', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mito', 'log1p_total_counts_mito', 'pct_counts_mito', 'region', 'instance_id'
#     var: 'gene_ids', 'feature_types', 'genome', 'mito', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'spatial', 'spatialdata_attrs'
#     obsm: 'spatial'
