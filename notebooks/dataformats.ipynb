# %% [markdown]
# Data curation: What is in the data folder

# %%
import pandas as pd
import os
from pathlib import Path
from natsort import natsorted, natsort_keygen
import numpy as np
import datetime as dt

# %%
DATA_DIR = os.environ.get('DATA_DIR', "/data/etienne.doumazane/theremia/hest_data")
DATA_DIR = Path(DATA_DIR)
natsorted(os.listdir(DATA_DIR))
# Out:
# ['HEST_v1_1_0.csv',
#  'MahmoodLab___hest',
#  'README.md',
#  '_data_etienne.doumazane_theremia_hest_data_MahmoodLab___hest_custom_config-patterns=%2A_1.0.0_94127ca856cb5f26aa6d5ab751be03921c2cc400b324e6285c015001d87154f7.lock',
#  'cellvit_seg',
#  'fig1_preview.jpg',
#  'fig1a.jpg',
#  'hest.py',
#  'human_gene_db.parquet',
#  'metadata',
#  'patches',
#  'patches_vis',
#  'pixel_size_vis',
#  'spatial_plots',
#  'st',
#  'thumbnails',
#  'tissue_seg',
#  'transcripts',
#  'wsis',
#  'xenium_seg']

# %%
natsorted(DATA_DIR.glob('*'))
# Out:
# [PosixPath('/data/etienne.doumazane/theremia/hest_data/HEST_v1_1_0.csv'),
#  PosixPath('/data/etienne.doumazane/theremia/hest_data/MahmoodLab___hest'),
#  PosixPath('/data/etienne.doumazane/theremia/hest_data/README.md'),
#  PosixPath('/data/etienne.doumazane/theremia/hest_data/_data_etienne.doumazane_theremia_hest_data_MahmoodLab___hest_custom_config-patterns=%2A_1.0.0_94127ca856cb5f26aa6d5ab751be03921c2cc400b324e6285c015001d87154f7.lock'),
#  PosixPath('/data/etienne.doumazane/theremia/hest_data/cellvit_seg'),
#  PosixPath('/data/etienne.doumazane/theremia/hest_data/fig1_preview.jpg'),
#  PosixPath('/data/etienne.doumazane/theremia/hest_data/fig1a.jpg'),
#  PosixPath('/data/etienne.doumazane/theremia/hest_data/hest.py'),
#  PosixPath('/data/etienne.doumazane/theremia/hest_data/human_gene_db.parquet'),
#  PosixPath('/data/etienne.doumazane/theremia/hest_data/metadata'),
#  PosixPath('/data/etienne.doumazane/theremia/hest_data/patches'),
#  PosixPath('/data/etienne.doumazane/theremia/hest_data/patches_vis'),
#  PosixPath('/data/etienne.doumazane/theremia/hest_data/pixel_size_vis'),
#  PosixPath('/data/etienne.doumazane/theremia/hest_data/spatial_plots'),
#  PosixPath('/data/etienne.doumazane/theremia/hest_data/st'),
#  PosixPath('/data/etienne.doumazane/theremia/hest_data/thumbnails'),
#  PosixPath('/data/etienne.doumazane/theremia/hest_data/tissue_seg'),
#  PosixPath('/data/etienne.doumazane/theremia/hest_data/transcripts'),
#  PosixPath('/data/etienne.doumazane/theremia/hest_data/wsis'),
#  PosixPath('/data/etienne.doumazane/theremia/hest_data/xenium_seg')]

# %%
def list_files_excluding_zarr(root_dir):
    root_path = Path(root_dir)

    for dirpath, dirnames, filenames in os.walk(root_path):
        # Skip directories that end with .zarr by removing them from dirnames
        dirnames[:] = [d for d in dirnames if not d.endswith('.zarr')]

        # Yield files from the current directory
        for filename in filenames:
            yield Path(dirpath) / filename

def create_table_1(dir):
    file_paths = natsorted(list_files_excluding_zarr(dir))
    df = pd.DataFrame(file_paths, columns=["path"])
    df["name"] = df["path"].apply(lambda x: x.name)
    # df["size_GB"] = df["path"].apply(lambda x: np.round(x.stat().st_size / 1e9, 1))
    df["size_MB"] = df["path"].apply(lambda x: np.round(x.stat().st_size / 1e6, 1))
    # df["size_kB"] = df["path"].apply(lambda x: np.round(x.stat().st_size / 1e3, 1))
    df["relative_path"] = df["path"].apply(lambda x: str(x.relative_to(DATA_DIR)))
    df["mtime"] = df["path"].apply(lambda x: dt.datetime.fromtimestamp(x.stat().st_mtime).isoformat(timespec="minutes"))
    df = df.sort_values("name", key=natsort_keygen()).reset_index(drop=True)
    df = df.sort_values("size_MB", ascending=False)
    df["extension"] = df["path"].apply(lambda x: x.suffix.upper())
    return df[df.columns.difference(["path"])].copy()

# %%
df = create_table_1(DATA_DIR)
df
# Out:
#       extension             mtime                         name  \
# 15190  .PARQUET  2024-12-03T22:29  TENX110_transcripts.parquet
# 15913  .PARQUET  2024-12-03T22:30  TENX159_transcripts.parquet
# 15109      .TIF  2024-12-04T15:42                   TENX98.tif
# 15715  .PARQUET  2024-12-03T22:28  TENX143_transcripts.parquet
# 15127      .TIF  2024-12-04T15:41                   TENX99.tif
# ...         ...               ...                          ...
# 2885      .JSON  2024-12-03T21:55                 MISC106.json
# 2897      .JSON  2024-12-03T21:55                 MISC107.json
# 2909      .JSON  2024-12-03T21:55                 MISC108.json
# 2849      .JSON  2024-12-03T21:55                 MISC103.json
# 2861      .JSON  2024-12-03T21:55                 MISC104.json
#
#                                  relative_path  size_MB
# 15190  transcripts/TENX110_transcripts.parquet  22052.2
# 15913  transcripts/TENX159_transcripts.parquet  15263.5
# 15109                          wsis/TENX98.tif  15062.2
# 15715  transcripts/TENX143_transcripts.parquet  13957.2
# 15127                          wsis/TENX99.tif  11784.3
# ...                                        ...      ...
# 2885                     metadata/MISC106.json      0.0
# 2897                     metadata/MISC107.json      0.0
# 2909                     metadata/MISC108.json      0.0
# 2849                     metadata/MISC103.json      0.0
# 2861                     metadata/MISC104.json      0.0
#
# [16194 rows x 5 columns]

# %%
df.extension.value_counts()
# Out:
# extension
# .PNG        2580
# .GEOJSON    2458
# .JPG        2218
# .PARQUET    1425
# .ZIP        1359
# .JSON       1230
# .H5         1229
# .TIF        1229
# .H5AD       1229
# .JPEG       1229
# .LOCK          3
# .CSV           1
# .ARROW         1
# .PY            1
# .MD            1
#                1
# Name: count, dtype: int64

# %%
df.groupby("extension")["size_MB"].mean()
# Out:
# extension
#               0.000000
# .ARROW        0.000000
# .CSV          0.500000
# .GEOJSON    105.496094
# .H5         232.722132
# .H5AD        61.336859
# .JPEG         0.130757
# .JPG          0.229982
# .JSON         0.000000
# .LOCK         0.000000
# .MD           0.000000
# .PARQUET    138.905754
# .PNG          0.564225
# .PY           0.000000
# .TIF        788.512937
# .ZIP         18.531126
# Name: size_MB, dtype: float64

# %%
list(df[df["extension"] == ".H5AD"]["relative_path"])
# Out:
# ['st/TENX70.h5ad',
#  'st/TENX72.h5ad',
#  'st/TENX81.h5ad',
#  'st/ZEN61.h5ad',
#  'st/TENX73.h5ad',
#  'st/TENX83.h5ad',
#  'st/TENX78.h5ad',
#  'st/TENX152.h5ad',
#  'st/TENX82.h5ad',
#  'st/TENX79.h5ad',
#  'st/ZEN60.h5ad',
#  'st/TENX84.h5ad',
#  'st/TENX77.h5ad',
#  'st/TENX74.h5ad',
#  'st/TENX65.h5ad',
#  'st/TENX71.h5ad',
#  'st/MISC62.h5ad',
#  'st/TENX86.h5ad',
#  'st/NCBI793.h5ad',
#  'st/NCBI682.h5ad',
#  'st/TENX85.h5ad',
#  'st/MISC63.h5ad',
#  'st/NCBI681.h5ad',
#  'st/NCBI776.h5ad',
#  'st/TENX88.h5ad',
#  'st/NCBI683.h5ad',
#  'st/MISC39.h5ad',
#  'st/MISC41.h5ad',
#  'st/INT23.h5ad',
#  'st/NCBI855.h5ad',
#  'st/TENX69.h5ad',
#  'st/INT27.h5ad',
#  'st/MEND76.h5ad',
#  'st/MISC40.h5ad',
#  'st/TENX75.h5ad',
#  'st/TENX16.h5ad',
#  'st/TENX51.h5ad',
#  'st/TENX87.h5ad',
#  'st/TENX76.h5ad',
#  'st/INT21.h5ad',
#  'st/MEND78.h5ad',
#  'st/TENX62.h5ad',
#  'st/NCBI684.h5ad',
#  'st/NCBI625.h5ad',
#  'st/INT18.h5ad',
#  'st/TENX91.h5ad',
#  'st/MISC65.h5ad',
#  'st/TENX45.h5ad',
#  'st/TENX90.h5ad',
#  'st/NCBI762.h5ad',
#  'st/MISC66.h5ad',
#  'st/MEND75.h5ad',
#  'st/MEND77.h5ad',
#  'st/TENX40.h5ad',
#  'st/NCBI623.h5ad',
#  'st/NCBI763.h5ad',
#  'st/NCBI626.h5ad',
#  'st/MEND130.h5ad',
#  'st/TENX14.h5ad',
#  'st/TENX155.h5ad',
#  'st/TENX128.h5ad',
#  'st/MISC35.h5ad',
#  'st/NCBI764.h5ad',
#  'st/MEND129.h5ad',
#  'st/INT28.h5ad',
#  'st/MISC50.h5ad',
#  'st/TENX154.h5ad',
#  'st/MEND60.h5ad',
#  'st/TENX146.h5ad',
#  'st/TENX13.h5ad',
#  'st/TENX156.h5ad',
#  'st/MISC67.h5ad',
#  'st/NCBI627.h5ad',
#  'st/TENX89.h5ad',
#  'st/MISC72.h5ad',
#  'st/NCBI624.h5ad',
#  'st/TENX46.h5ad',
#  'st/MISC64.h5ad',
#  'st/MISC73.h5ad',
#  'st/TENX92.h5ad',
#  'st/TENX49.h5ad',
#  'st/TENX153.h5ad',
#  'st/NCBI837.h5ad',
#  'st/INT22.h5ad',
#  'st/INT15.h5ad',
#  'st/TENX53.h5ad',
#  'st/MEND59.h5ad',
#  'st/NCBI716.h5ad',
#  'st/NCBI621.h5ad',
#  'st/MISC36.h5ad',
#  'st/TENX50.h5ad',
#  'st/NCBI717.h5ad',
#  'st/NCBI569.h5ad',
#  'st/NCBI618.h5ad',
#  'st/NCBI718.h5ad',
#  'st/NCBI622.h5ad',
#  'st/NCBI719.h5ad',
#  'st/INT25.h5ad',
#  'st/NCBI834.h5ad',
#  'st/INT13.h5ad',
#  'st/TENX144.h5ad',
#  'st/TENX129.h5ad',
#  'st/TENX145.h5ad',
#  'st/TENX80.h5ad',
#  'st/INT14.h5ad',
#  'st/TENX24.h5ad',
#  'st/NCBI620.h5ad',
#  'st/NCBI720.h5ad',
#  'st/MISC37.h5ad',
#  'st/NCBI715.h5ad',
#  'st/TENX52.h5ad',
#  'st/TENX18.h5ad',
#  'st/NCBI792.h5ad',
#  'st/TENX19.h5ad',
#  'st/INT26.h5ad',
#  'st/TENX131.h5ad',
#  'st/TENX31.h5ad',
#  'st/MISC34.h5ad',
#  'st/TENX60.h5ad',
#  'st/NCBI835.h5ad',
#  'st/NCBI801.h5ad',
#  'st/NCBI366.h5ad',
#  'st/NCBI728.h5ad',
#  'st/TENX54.h5ad',
#  'st/TENX27.h5ad',
#  'st/MEND74.h5ad',
#  'st/TENX55.h5ad',
#  'st/NCBI371.h5ad',
#  'st/NCBI619.h5ad',
#  'st/NCBI843.h5ad',
#  'st/NCBI365.h5ad',
#  'st/ZEN79.h5ad',
#  'st/INT24.h5ad',
#  'st/NCBI364.h5ad',
#  'st/NCBI368.h5ad',
#  'st/NCBI374.h5ad',
#  'st/NCBI378.h5ad',
#  'st/MISC46.h5ad',
#  'st/NCBI802.h5ad',
#  'st/NCBI375.h5ad',
#  'st/NCBI369.h5ad',
#  'st/NCBI384.h5ad',
#  'st/NCBI379.h5ad',
#  'st/NCBI385.h5ad',
#  'st/NCBI572.h5ad',
#  'st/NCBI377.h5ad',
#  'st/NCBI370.h5ad',
#  'st/ZEN78.h5ad',
#  'st/NCBI367.h5ad',
#  'st/NCBI376.h5ad',
#  'st/TENX43.h5ad',
#  'st/NCBI786.h5ad',
#  'st/NCBI832.h5ad',
#  'st/MISC130.h5ad',
#  'st/MISC129.h5ad',
#  'st/NCBI381.h5ad',
#  'st/NCBI643.h5ad',
#  'st/SPA99.h5ad',
#  'st/NCBI373.h5ad',
#  'st/NCBI383.h5ad',
#  'st/NCBI629.h5ad',
#  'st/NCBI570.h5ad',
#  'st/MEND72.h5ad',
#  'st/NCBI362.h5ad',
#  'st/NCBI658.h5ad',
#  'st/NCBI353.h5ad',
#  'st/MISC51.h5ad',
#  'st/NCBI800.h5ad',
#  'st/NCBI382.h5ad',
#  'st/NCBI388.h5ad',
#  'st/INT16.h5ad',
#  'st/NCBI799.h5ad',
#  'st/MISC49.h5ad',
#  'st/INT20.h5ad',
#  'st/NCBI789.h5ad',
#  'st/TENX67.h5ad',
#  'st/SPA100.h5ad',
#  'st/SPA55.h5ad',
#  'st/NCBI372.h5ad',
#  'st/NCBI854.h5ad',
#  'st/NCBI361.h5ad',
#  'st/SPA101.h5ad',
#  'st/NCBI354.h5ad',
#  'st/MEND61.h5ad',
#  'st/NCBI352.h5ad',
#  'st/ZEN80.h5ad',
#  'st/NCBI391.h5ad',
#  'st/NCBI380.h5ad',
#  'st/TENX39.h5ad',
#  'st/INT19.h5ad',
#  'st/MISC128.h5ad',
#  'st/NCBI393.h5ad',
#  'st/NCBI841.h5ad',
#  'st/NCBI836.h5ad',
#  'st/NCBI386.h5ad',
#  'st/NCBI687.h5ad',
#  'st/NCBI360.h5ad',
#  'st/NCBI363.h5ad',
#  'st/NCBI668.h5ad',
#  'st/NCBI389.h5ad',
#  'st/NCBI688.h5ad',
#  'st/NCBI729.h5ad',
#  'st/NCBI829.h5ad',
#  'st/NCBI597.h5ad',
#  'st/ZEN81.h5ad',
#  'st/TENX61.h5ad',
#  'st/TENX29.h5ad',
#  'st/NCBI390.h5ad',
#  'st/NCBI359.h5ad',
#  'st/NCBI394.h5ad',
#  'st/NCBI844.h5ad',
#  'st/NCBI350.h5ad',
#  'st/INT35.h5ad',
#  'st/NCBI398.h5ad',
#  'st/MISC48.h5ad',
#  'st/NCBI392.h5ad',
#  'st/NCBI770.h5ad',
#  'st/NCBI768.h5ad',
#  'st/NCBI842.h5ad',
#  'st/MEND139.h5ad',
#  'st/NCBI351.h5ad',
#  'st/NCBI808.h5ad',
#  'st/NCBI689.h5ad',
#  'st/NCBI669.h5ad',
#  'st/MEND124.h5ad',
#  'st/MEND73.h5ad',
#  'st/NCBI348.h5ad',
#  'st/NCBI349.h5ad',
#  'st/NCBI769.h5ad',
#  'st/MEND64.h5ad',
#  'st/MISC16.h5ad',
#  'st/MISC127.h5ad',
#  'st/INT7.h5ad',
#  'st/NCBI571.h5ad',
#  'st/NCBI395.h5ad',
#  'st/NCBI357.h5ad',
#  'st/MEND123.h5ad',
#  'st/NCBI673.h5ad',
#  'st/NCBI596.h5ad',
#  'st/TENX157.h5ad',
#  'st/NCBI833.h5ad',
#  'st/SPA95.h5ad',
#  'st/NCBI356.h5ad',
#  'st/NCBI397.h5ad',
#  'st/SPA54.h5ad',
#  'st/NCBI641.h5ad',
#  'st/NCBI358.h5ad',
#  'st/NCBI635.h5ad',
#  'st/SPA56.h5ad',
#  'st/SPA72.h5ad',
#  'st/SPA125.h5ad',
#  'st/NCBI686.h5ad',
#  'st/NCBI598.h5ad',
#  'st/NCBI355.h5ad',
#  'st/SPA94.h5ad',
#  'st/NCBI680.h5ad',
#  'st/MEND62.h5ad',
#  'st/SPA126.h5ad',
#  'st/MISC71.h5ad',
#  'st/INT8.h5ad',
#  'st/NCBI760.h5ad',
#  'st/SPA103.h5ad',
#  'st/MISC3.h5ad',
#  'st/NCBI637.h5ad',
#  'st/SPA102.h5ad',
#  'st/MEND156.h5ad',
#  'st/SPA127.h5ad',
#  'st/NCBI642.h5ad',
#  'st/SPA104.h5ad',
#  'st/NCBI387.h5ad',
#  'st/NCBI787.h5ad',
#  'st/SPA82.h5ad',
#  'st/NCBI838.h5ad',
#  'st/NCBI638.h5ad',
#  'st/NCBI630.h5ad',
#  'st/NCBI685.h5ad',
#  'st/NCBI347.h5ad',
#  'st/SPA83.h5ad',
#  'st/NCBI767.h5ad',
#  'st/ZEN47.h5ad',
#  'st/NCBI660.h5ad',
#  'st/SPA33.h5ad',
#  'st/NCBI659.h5ad',
#  'st/SPA34.h5ad',
#  'st/NCBI727.h5ad',
#  'st/NCBI839.h5ad',
#  'st/INT10.h5ad',
#  'st/MISC45.h5ad',
#  'st/NCBI346.h5ad',
#  'st/ZEN49.h5ad',
#  'st/SPA35.h5ad',
#  'st/MISC126.h5ad',
#  'st/TENX68.h5ad',
#  'st/SPA81.h5ad',
#  'st/ZEN48.h5ad',
#  'st/TENX143.h5ad',
#  'st/NCBI714.h5ad',
#  'st/NCBI599.h5ad',
#  'st/SPA70.h5ad',
#  'st/INT5.h5ad',
#  'st/MEND90.h5ad',
#  'st/NCBI344.h5ad',
#  'st/MEND63.h5ad',
#  'st/NCBI399.h5ad',
#  'st/SPA73.h5ad',
#  'st/MISC15.h5ad',
#  'st/MISC38.h5ad',
#  'st/SPA66.h5ad',
#  'st/NCBI761.h5ad',
#  'st/SPA71.h5ad',
#  'st/SPA32.h5ad',
#  'st/NCBI633.h5ad',
#  'st/NCBI400.h5ad',
#  'st/NCBI766.h5ad',
#  'st/NCBI840.h5ad',
#  'st/NCBI830.h5ad',
#  'st/SPA74.h5ad',
#  'st/ZEN36.h5ad',
#  'st/SPA130.h5ad',
#  'st/SPA121.h5ad',
#  'st/INT17.h5ad',
#  'st/MISC119.h5ad',
#  'st/NCBI345.h5ad',
#  'st/NCBI765.h5ad',
#  'st/MISC70.h5ad',
#  'st/MEND71.h5ad',
#  'st/NCBI664.h5ad',
#  'st/SPA63.h5ad',
#  'st/SPA68.h5ad',
#  'st/SPA93.h5ad',
#  'st/SPA69.h5ad',
#  'st/NCBI828.h5ad',
#  'st/NCBI396.h5ad',
#  'st/SPA120.h5ad',
#  'st/SPA67.h5ad',
#  'st/NCBI634.h5ad',
#  'st/SPA65.h5ad',
#  'st/SPA40.h5ad',
#  'st/MISC47.h5ad',
#  'st/SPA88.h5ad',
#  'st/TENX15.h5ad',
#  'st/NCBI827.h5ad',
#  'st/NCBI712.h5ad',
#  'st/NCBI648.h5ad',
#  'st/SPA30.h5ad',
#  'st/SPA129.h5ad',
#  'st/ZEN46.h5ad',
#  'st/SPA39.h5ad',
#  'st/SPA128.h5ad',
#  'st/SPA87.h5ad',
#  'st/SPA97.h5ad',
#  'st/NCBI675.h5ad',
#  'st/NCBI402.h5ad',
#  'st/SPA58.h5ad',
#  'st/MISC4.h5ad',
#  'st/NCBI401.h5ad',
#  'st/TENX22.h5ad',
#  'st/SPA96.h5ad',
#  'st/SPA57.h5ad',
#  'st/NCBI632.h5ad',
#  'st/MEND154.h5ad',
#  'st/MEND89.h5ad',
#  'st/SPA31.h5ad',
#  'st/NCBI807.h5ad',
#  'st/SPA59.h5ad',
#  'st/SPA51.h5ad',
#  'st/MISC6.h5ad',
#  'st/MISC56.h5ad',
#  'st/TENX159.h5ad',
#  'st/SPA64.h5ad',
#  'st/SPA85.h5ad',
#  'st/MEND157.h5ad',
#  'st/SPA53.h5ad',
#  'st/NCBI640.h5ad',
#  'st/NCBI759.h5ad',
#  'st/SPA98.h5ad',
#  'st/MISC122.h5ad',
#  'st/SPA109.h5ad',
#  'st/SPA86.h5ad',
#  'st/NCBI662.h5ad',
#  'st/NCBI824.h5ad',
#  'st/SPA41.h5ad',
#  'st/NCBI403.h5ad',
#  'st/NCBI672.h5ad',
#  'st/SPA89.h5ad',
#  'st/MEND161.h5ad',
#  'st/SPA84.h5ad',
#  'st/MEND29.h5ad',
#  'st/MISC118.h5ad',
#  'st/SPA110.h5ad',
#  'st/SPA119.h5ad',
#  'st/SPA105.h5ad',
#  'st/NCBI562.h5ad',
#  'st/SPA37.h5ad',
#  'st/SPA108.h5ad',
#  'st/MISC5.h5ad',
#  'st/TENX41.h5ad',
#  'st/SPA36.h5ad',
#  'st/MEND142.h5ad',
#  'st/NCBI636.h5ad',
#  'st/NCBI2.h5ad',
#  'st/SPA106.h5ad',
#  'st/NCBI790.h5ad',
#  'st/SPA38.h5ad',
#  'st/MEND143.h5ad',
#  'st/MISC10.h5ad',
#  'st/SPA107.h5ad',
#  'st/MISC120.h5ad',
#  'st/ZEN40.h5ad',
#  'st/NCBI631.h5ad',
#  'st/NCBI809.h5ad',
#  'st/MISC1.h5ad',
#  'st/NCBI646.h5ad',
#  'st/SPA123.h5ad',
#  'st/NCBI674.h5ad',
#  'st/MISC8.h5ad',
#  'st/INT12.h5ad',
#  'st/NCBI103.h5ad',
#  'st/SPA122.h5ad',
#  'st/INT9.h5ad',
#  'st/MISC2.h5ad',
#  'st/NCBI665.h5ad',
#  'st/NCBI528.h5ad',
#  'st/MEND42.h5ad',
#  'st/NCBI713.h5ad',
#  'st/MISC9.h5ad',
#  'st/NCBI831.h5ad',
#  'st/NCBI666.h5ad',
#  'st/MEND35.h5ad',
#  'st/NCBI404.h5ad',
#  'st/MEND144.h5ad',
#  'st/NCBI823.h5ad',
#  'st/NCBI106.h5ad',
#  'st/NCBI461.h5ad',
#  'st/MEND53.h5ad',
#  'st/NCBI527.h5ad',
#  'st/MISC124.h5ad',
#  'st/MISC113.h5ad',
#  'st/NCBI57.h5ad',
#  'st/SPA42.h5ad',
#  'st/NCBI341.h5ad',
#  'st/SPA124.h5ad',
#  'st/NCBI670.h5ad',
#  'st/NCBI825.h5ad',
#  'st/MISC125.h5ad',
#  'st/MISC121.h5ad',
#  'st/MEND30.h5ad',
#  'st/NCBI340.h5ad',
#  'st/SPA78.h5ad',
#  'st/NCBI405.h5ad',
#  'st/SPA52.h5ad',
#  'st/SPA80.h5ad',
#  'st/MEND17.h5ad',
#  'st/SPA79.h5ad',
#  'st/MISC12.h5ad',
#  'st/NCBI108.h5ad',
#  'st/NCBI812.h5ad',
#  'st/MEND31.h5ad',
#  'st/NCBI639.h5ad',
#  'st/NCBI406.h5ad',
#  'st/NCBI671.h5ad',
#  'st/MISC140.h5ad',
#  'st/MEND34.h5ad',
#  'st/MEND150.h5ad',
#  'st/NCBI711.h5ad',
#  'st/MISC7.h5ad',
#  'st/INT6.h5ad',
#  'st/NCBI55.h5ad',
#  'st/NCBI811.h5ad',
#  'st/NCBI120.h5ad',
#  'st/MEND32.h5ad',
#  'st/NCBI663.h5ad',
#  'st/SPA115.h5ad',
#  'st/NCBI104.h5ad',
#  'st/MISC33.h5ad',
#  'st/NCBI806.h5ad',
#  'st/MISC123.h5ad',
#  'st/SPA60.h5ad',
#  'st/MEND36.h5ad',
#  'st/SPA90.h5ad',
#  'st/NCBI574.h5ad',
#  'st/NCBI826.h5ad',
#  'st/NCBI105.h5ad',
#  'st/NCBI126.h5ad',
#  'st/MEND152.h5ad',
#  'st/SPA113.h5ad',
#  'st/SPA116.h5ad',
#  'st/NCBI813.h5ad',
#  'st/MEND140.h5ad',
#  'st/NCBI667.h5ad',
#  'st/NCBI268.h5ad',
#  'st/NCBI647.h5ad',
#  'st/MEND40.h5ad',
#  'st/NCBI822.h5ad',
#  'st/NCBI821.h5ad',
#  'st/TENX58.h5ad',
#  'st/NCBI342.h5ad',
#  'st/NCBI117.h5ad',
#  'st/SPA92.h5ad',
#  'st/SPA61.h5ad',
#  'st/ZEN42.h5ad',
#  'st/MEND33.h5ad',
#  'st/NCBI339.h5ad',
#  'st/MEND151.h5ad',
#  'st/NCBI788.h5ad',
#  'st/NCBI650.h5ad',
#  'st/NCBI123.h5ad',
#  'st/INT11.h5ad',
#  'st/NCBI338.h5ad',
#  'st/MISC11.h5ad',
#  'st/NCBI408.h5ad',
#  'st/SPA114.h5ad',
#  'st/NCBI132.h5ad',
#  'st/SPA149.h5ad',
#  'st/NCBI125.h5ad',
#  'st/SPA117.h5ad',
#  'st/NCBI343.h5ad',
#  'st/NCBI184.h5ad',
#  'st/NCBI178.h5ad',
#  'st/SPA152.h5ad',
#  'st/NCBI119.h5ad',
#  'st/NCBI128.h5ad',
#  'st/NCBI272.h5ad',
#  'st/NCBI130.h5ad',
#  'st/NCBI269.h5ad',
#  'st/NCBI114.h5ad',
#  'st/INT2.h5ad',
#  'st/NCBI573.h5ad',
#  'st/NCBI649.h5ad',
#  'st/NCBI628.h5ad',
#  'st/NCBI124.h5ad',
#  'st/MISC132.h5ad',
#  'st/NCBI111.h5ad',
#  'st/ZEN37.h5ad',
#  'st/SPA91.h5ad',
#  'st/NCBI118.h5ad',
#  'st/MEND158.h5ad',
#  'st/NCBI51.h5ad',
#  'st/SPA151.h5ad',
#  'st/NCBI594.h5ad',
#  'st/NCBI66.h5ad',
#  'st/SPA112.h5ad',
#  'st/MISC111.h5ad',
#  'st/NCBI258.h5ad',
#  'st/MISC139.h5ad',
#  'st/SPA111.h5ad',
#  'st/NCBI568.h5ad',
#  'st/TENX158.h5ad',
#  'st/NCBI211.h5ad',
#  'st/NCBI464.h5ad',
#  'st/MEND160.h5ad',
#  'st/SPA75.h5ad',
#  'st/NCBI107.h5ad',
#  'st/SPA154.h5ad',
#  'st/SPA150.h5ad',
#  'st/NCBI542.h5ad',
#  'st/NCBI218.h5ad',
#  'st/NCBI407.h5ad',
#  'st/SPA76.h5ad',
#  'st/MEND18.h5ad',
#  'st/NCBI112.h5ad',
#  'st/NCBI205.h5ad',
#  'st/SPA77.h5ad',
#  'st/NCBI56.h5ad',
#  'st/MEND153.h5ad',
#  'st/NCBI110.h5ad',
#  'st/NCBI100.h5ad',
#  'st/NCBI135.h5ad',
#  'st/MEND6.h5ad',
#  'st/NCBI336.h5ad',
#  'st/NCBI467.h5ad',
#  'st/SPA153.h5ad',
#  'st/NCBI243.h5ad',
#  'st/NCBI217.h5ad',
#  'st/NCBI46.h5ad',
#  'st/NCBI152.h5ad',
#  'st/NCBI181.h5ad',
#  'st/MEND27.h5ad',
#  'st/NCBI133.h5ad',
#  'st/NCBI29.h5ad',
#  'st/NCBI214.h5ad',
#  'st/NCBI169.h5ad',
#  'st/NCBI221.h5ad',
#  'st/SPA62.h5ad',
#  'st/MISC133.h5ad',
#  'st/NCBI230.h5ad',
#  'st/NCBI43.h5ad',
#  'st/MEND65.h5ad',
#  'st/NCBI127.h5ad',
#  'st/NCBI54.h5ad',
#  'st/NCBI45.h5ad',
#  'st/NCBI166.h5ad',
#  'st/ZEN41.h5ad',
#  'st/MISC117.h5ad',
#  'st/NCBI47.h5ad',
#  'st/MEND14.h5ad',
#  'st/MEND80.h5ad',
#  'st/NCBI5.h5ad',
#  'st/MEND3.h5ad',
#  'st/NCBI67.h5ad',
#  'st/NCBI134.h5ad',
#  'st/MEND5.h5ad',
#  'st/INT3.h5ad',
#  'st/NCBI154.h5ad',
#  'st/NCBI160.h5ad',
#  'st/MEND11.h5ad',
#  'st/MEND28.h5ad',
#  'st/SPA131.h5ad',
#  'st/NCBI28.h5ad',
#  'st/NCBI157.h5ad',
#  'st/NCBI146.h5ad',
#  'st/NCBI661.h5ad',
#  'st/NCBI163.h5ad',
#  'st/NCBI177.h5ad',
#  'st/NCBI257.h5ad',
#  'st/NCBI68.h5ad',
#  'st/NCBI99.h5ad',
#  'st/NCBI164.h5ad',
#  'st/SPA136.h5ad',
#  'st/NCBI180.h5ad',
#  'st/NCBI182.h5ad',
#  'st/SPA132.h5ad',
#  'st/MEND2.h5ad',
#  'st/NCBI266.h5ad',
#  'st/NCBI652.h5ad',
#  'st/NCBI468.h5ad',
#  'st/NCBI601.h5ad',
#  'st/NCBI148.h5ad',
#  'st/NCBI42.h5ad',
#  'st/NCBI224.h5ad',
#  'st/NCBI131.h5ad',
#  'st/NCBI113.h5ad',
#  'st/NCBI151.h5ad',
#  'st/NCBI261.h5ad',
#  'st/SPA133.h5ad',
#  'st/NCBI409.h5ad',
#  'st/NCBI543.h5ad',
#  'st/NCBI210.h5ad',
#  'st/NCBI147.h5ad',
#  'st/NCBI195.h5ad',
#  'st/SPA134.h5ad',
#  'st/NCBI63.h5ad',
#  'st/NCBI44.h5ad',
#  'st/NCBI129.h5ad',
#  'st/SPA135.h5ad',
#  'st/MEND1.h5ad',
#  'st/NCBI61.h5ad',
#  'st/MEND12.h5ad',
#  'st/MISC131.h5ad',
#  'st/NCBI176.h5ad',
#  'st/NCBI22.h5ad',
#  'st/SPA6.h5ad',
#  'st/NCBI207.h5ad',
#  'st/NCBI225.h5ad',
#  'st/NCBI167.h5ad',
#  'st/MISC138.h5ad',
#  'st/MEND147.h5ad',
#  'st/MISC112.h5ad',
#  'st/NCBI138.h5ad',
#  'st/NCBI97.h5ad',
#  'st/NCBI270.h5ad',
#  'st/NCBI155.h5ad',
#  'st/NCBI153.h5ad',
#  'st/NCBI109.h5ad',
#  'st/NCBI260.h5ad',
#  'st/NCBI170.h5ad',
#  'st/NCBI209.h5ad',
#  'st/SPA146.h5ad',
#  'st/SPA4.h5ad',
#  'st/NCBI267.h5ad',
#  'st/NCBI98.h5ad',
#  'st/MEND15.h5ad',
#  'st/MEND38.h5ad',
#  'st/NCBI198.h5ad',
#  'st/SPA14.h5ad',
#  'st/NCBI337.h5ad',
#  'st/NCBI144.h5ad',
#  'st/SPA148.h5ad',
#  'st/NCBI216.h5ad',
#  'st/NCBI222.h5ad',
#  'st/SPA43.h5ad',
#  'st/NCBI139.h5ad',
#  'st/NCBI212.h5ad',
#  'st/NCBI194.h5ad',
#  'st/SPA15.h5ad',
#  'st/NCBI69.h5ad',
#  'st/MISC68.h5ad',
#  'st/NCBI149.h5ad',
#  'st/NCBI256.h5ad',
#  'st/MISC26.h5ad',
#  'st/NCBI141.h5ad',
#  'st/SPA44.h5ad',
#  'st/SPA144.h5ad',
#  'st/MISC141.h5ad',
#  'st/MEND9.h5ad',
#  'st/NCBI115.h5ad',
#  'st/NCBI201.h5ad',
#  'st/NCBI165.h5ad',
#  'st/NCBI271.h5ad',
#  'st/NCBI602.h5ad',
#  'st/NCBI102.h5ad',
#  'st/NCBI161.h5ad',
#  'st/NCBI227.h5ad',
#  'st/NCBI156.h5ad',
#  'st/MEND20.h5ad',
#  'st/NCBI234.h5ad',
#  'st/SPA145.h5ad',
#  'st/NCBI150.h5ad',
#  'st/MEND149.h5ad',
#  'st/SPA118.h5ad',
#  'st/SPA13.h5ad',
#  'st/NCBI137.h5ad',
#  'st/NCBI247.h5ad',
#  'st/NCBI53.h5ad',
#  'st/NCBI197.h5ad',
#  'st/NCBI23.h5ad',
#  'st/SPA143.h5ad',
#  'st/SPA5.h5ad',
#  'st/NCBI215.h5ad',
#  'st/NCBI7.h5ad',
#  'st/SPA12.h5ad',
#  'st/NCBI9.h5ad',
#  'st/NCBI278.h5ad',
#  'st/NCBI236.h5ad',
#  'st/NCBI206.h5ad',
#  'st/NCBI463.h5ad',
#  'st/NCBI173.h5ad',
#  'st/NCBI190.h5ad',
#  'st/NCBI122.h5ad',
#  'st/MEND141.h5ad',
#  'st/NCBI690.h5ad',
#  'st/SPA147.h5ad',
#  'st/NCBI145.h5ad',
#  'st/MEND159.h5ad',
#  'st/NCBI282.h5ad',
#  'st/MEND13.h5ad',
#  'st/NCBI60.h5ad',
#  'st/NCBI116.h5ad',
#  'st/NCBI189.h5ad',
#  'st/MISC43.h5ad',
#  'st/SPA11.h5ad',
#  'st/NCBI228.h5ad',
#  'st/NCBI143.h5ad',
#  'st/NCBI4.h5ad',
#  'st/NCBI193.h5ad',
#  'st/MEND79.h5ad',
#  'st/NCBI231.h5ad',
#  'st/NCBI820.h5ad',
#  'st/NCBI39.h5ad',
#  'st/NCBI203.h5ad',
#  'st/NCBI196.h5ad',
#  'st/NCBI237.h5ad',
#  'st/NCBI171.h5ad',
#  'st/NCBI65.h5ad',
#  'st/MISC13.h5ad',
#  'st/NCBI651.h5ad',
#  'st/NCBI204.h5ad',
#  'st/NCBI276.h5ad',
#  'st/ZEN44.h5ad',
#  'st/NCBI213.h5ad',
#  'st/NCBI101.h5ad',
#  'st/NCBI533.h5ad',
#  'st/NCBI563.h5ad',
#  'st/NCBI64.h5ad',
#  'st/MEND55.h5ad',
#  'st/NCBI158.h5ad',
#  'st/SPA10.h5ad',
#  'st/SPA1.h5ad',
#  'st/NCBI121.h5ad',
#  'st/NCBI191.h5ad',
#  'st/NCBI575.h5ad',
#  'st/MEND19.h5ad',
#  'st/NCBI179.h5ad',
#  'st/NCBI36.h5ad',
#  'st/NCBI595.h5ad',
#  'st/MEND22.h5ad',
#  'st/MEND21.h5ad',
#  'st/NCBI229.h5ad',
#  'st/SPA0.h5ad',
#  'st/SPA9.h5ad',
#  'st/MISC114.h5ad',
#  'st/MISC59.h5ad',
#  'st/NCBI24.h5ad',
#  'st/NCBI199.h5ad',
#  'st/MISC22.h5ad',
#  'st/NCBI691.h5ad',
#  'st/NCBI245.h5ad',
#  'st/NCBI275.h5ad',
#  'st/NCBI233.h5ad',
#  'st/NCBI25.h5ad',
#  'st/NCBI17.h5ad',
#  'st/NCBI140.h5ad',
#  'st/MEND16.h5ad',
#  'st/NCBI49.h5ad',
#  'st/NCBI35.h5ad',
#  'st/NCBI244.h5ad',
#  'st/TENX110.h5ad',
#  'st/NCBI136.h5ad',
#  'st/SPA3.h5ad',
#  'st/NCBI232.h5ad',
#  'st/MISC134.h5ad',
#  'st/NCBI192.h5ad',
#  'st/NCBI446.h5ad',
#  'st/MEND82.h5ad',
#  'st/NCBI262.h5ad',
#  'st/MEND39.h5ad',
#  'st/MEND25.h5ad',
#  'st/NCBI286.h5ad',
#  'st/NCBI41.h5ad',
#  'st/MEND24.h5ad',
#  'st/SPA2.h5ad',
#  'st/NCBI48.h5ad',
#  'st/NCBI655.h5ad',
#  'st/NCBI254.h5ad',
#  'st/MISC14.h5ad',
#  'st/NCBI187.h5ad',
#  'st/NCBI240.h5ad',
#  'st/NCBI410.h5ad',
#  'st/NCBI238.h5ad',
#  'st/TENX98.h5ad',
#  'st/NCBI58.h5ad',
#  'st/NCBI567.h5ad',
#  'st/ZEN43.h5ad',
#  'st/NCBI15.h5ad',
#  'st/SPA7.h5ad',
#  'st/NCBI162.h5ad',
#  'st/SPA8.h5ad',
#  'st/NCBI450.h5ad',
#  'st/NCBI52.h5ad',
#  'st/NCBI263.h5ad',
#  'st/NCBI38.h5ad',
#  'st/NCBI159.h5ad',
#  'st/MISC116.h5ad',
#  'st/MISC57.h5ad',
#  'st/MISC135.h5ad',
#  'st/NCBI200.h5ad',
#  'st/NCBI183.h5ad',
#  'st/NCBI281.h5ad',
#  'st/MISC61.h5ad',
#  'st/NCBI6.h5ad',
#  'st/NCBI287.h5ad',
#  'st/NCBI219.h5ad',
#  'st/NCBI62.h5ad',
#  'st/NCBI208.h5ad',
#  'st/NCBI255.h5ad',
#  'st/NCBI20.h5ad',
#  'st/NCBI439.h5ad',
#  'st/NCBI50.h5ad',
#  'st/NCBI18.h5ad',
#  'st/NCBI174.h5ad',
#  'st/MEND81.h5ad',
#  'st/NCBI168.h5ad',
#  'st/NCBI443.h5ad',
#  'st/NCBI264.h5ad',
#  'st/NCBI794.h5ad',
#  'st/MISC107.h5ad',
#  'st/NCBI451.h5ad',
#  'st/NCBI259.h5ad',
#  'st/NCBI142.h5ad',
#  'st/NCBI8.h5ad',
#  'st/NCBI27.h5ad',
#  'st/NCBI444.h5ad',
#  'st/NCBI438.h5ad',
#  'st/NCBI226.h5ad',
#  'st/NCBI241.h5ad',
#  'st/TENX99.h5ad',
#  'st/NCBI34.h5ad',
#  'st/NCBI462.h5ad',
#  'st/NCBI223.h5ad',
#  'st/NCBI253.h5ad',
#  'st/NCBI175.h5ad',
#  'st/MEND4.h5ad',
#  'st/MISC109.h5ad',
#  'st/MEND8.h5ad',
#  'st/NCBI251.h5ad',
#  'st/NCBI242.h5ad',
#  'st/NCBI186.h5ad',
#  'st/NCBI239.h5ad',
#  'st/NCBI791.h5ad',
#  'st/MEND26.h5ad',
#  'st/NCBI695.h5ad',
#  'st/NCBI246.h5ad',
#  'st/NCBI434.h5ad',
#  'st/NCBI265.h5ad',
#  'st/NCBI440.h5ad',
#  'st/NCBI565.h5ad',
#  'st/NCBI21.h5ad',
#  'st/MISC69.h5ad',
#  'st/MISC142.h5ad',
#  'st/NCBI202.h5ad',
#  'st/NCBI172.h5ad',
#  'st/SPA46.h5ad',
#  'st/NCBI37.h5ad',
#  'st/NCBI33.h5ad',
#  'st/NCBI819.h5ad',
#  'st/NCBI26.h5ad',
#  'st/NCBI185.h5ad',
#  'st/MEND145.h5ad',
#  'st/NCBI252.h5ad',
#  'st/MEND44.h5ad',
#  'st/NCBI531.h5ad',
#  'st/NCBI220.h5ad',
#  'st/MISC106.h5ad',
#  'st/NCBI591.h5ad',
#  'st/NCBI235.h5ad',
#  'st/NCBI31.h5ad',
#  'st/MISC58.h5ad',
#  'st/MEND146.h5ad',
#  'st/MISC104.h5ad',
#  'st/NCBI13.h5ad',
#  'st/NCBI448.h5ad',
#  'st/MEND46.h5ad',
#  'st/NCBI654.h5ad',
#  'st/NCBI529.h5ad',
#  'st/NCBI277.h5ad',
#  'st/SPA141.h5ad',
#  'st/NCBI30.h5ad',
#  'st/SPA139.h5ad',
#  'st/NCBI445.h5ad',
#  'st/NCBI709.h5ad',
#  'st/NCBI708.h5ad',
#  'st/MEND10.h5ad',
#  'st/NCBI1.h5ad',
#  'st/MISC108.h5ad',
#  'st/NCBI566.h5ad',
#  'st/NCBI40.h5ad',
#  'st/MEND23.h5ad',
#  'st/MEND37.h5ad',
#  'st/NCBI603.h5ad',
#  'st/SPA138.h5ad',
#  'st/SPA140.h5ad',
#  'st/NCBI449.h5ad',
#  'st/NCBI696.h5ad',
#  'st/NCBI435.h5ad',
#  'st/MEND66.h5ad',
#  'st/SPA137.h5ad',
#  'st/NCBI279.h5ad',
#  'st/INT1.h5ad',
#  'st/MEND50.h5ad',
#  'st/NCBI795.h5ad',
#  'st/NCBI532.h5ad',
#  'st/MEND162.h5ad',
#  'st/SPA142.h5ad',
#  'st/MISC103.h5ad',
#  'st/NCBI280.h5ad',
#  'st/NCBI441.h5ad',
#  'st/NCBI437.h5ad',
#  'st/MEND96.h5ad',
#  'st/NCBI188.h5ad',
#  'st/NCBI283.h5ad',
#  'st/MEND43.h5ad',
#  'st/SPA47.h5ad',
#  'st/NCBI530.h5ad',
#  'st/NCBI273.h5ad',
#  'st/NCBI442.h5ad',
#  'st/NCBI592.h5ad',
#  'st/NCBI11.h5ad',
#  'st/NCBI710.h5ad',
#  'st/NCBI699.h5ad',
#  'st/NCBI452.h5ad',
#  'st/MISC136.h5ad',
#  'st/MEND87.h5ad',
#  'st/MISC115.h5ad',
#  'st/NCBI656.h5ad',
#  'st/NCBI693.h5ad',
#  'st/MISC31.h5ad',
#  'st/SPA45.h5ad',
#  'st/SPA48.h5ad',
#  'st/NCBI593.h5ad',
#  'st/MISC110.h5ad',
#  'st/NCBI653.h5ad',
#  'st/NCBI32.h5ad',
#  'st/MISC53.h5ad',
#  'st/NCBI284.h5ad',
#  'st/NCBI515.h5ad',
#  'st/NCBI274.h5ad',
#  'st/NCBI503.h5ad',
#  'st/NCBI290.h5ad',
#  'st/NCBI700.h5ad',
#  'st/NCBI706.h5ad',
#  'st/MISC20.h5ad',
#  'st/MISC105.h5ad',
#  'st/NCBI816.h5ad',
#  'st/NCBI701.h5ad',
#  'st/MEND131.h5ad',
#  'st/MISC30.h5ad',
#  'st/NCBI14.h5ad',
#  'st/NCBI447.h5ad',
#  'st/NCBI504.h5ad',
#  'st/NCBI248.h5ad',
#  'st/NCBI10.h5ad',
#  'st/MISC44.h5ad',
#  'st/NCBI576.h5ad',
#  'st/NCBI291.h5ad',
#  'st/NCBI19.h5ad',
#  'st/NCBI285.h5ad',
#  'st/NCBI600.h5ad',
#  'st/ZEN39.h5ad',
#  'st/NCBI289.h5ad',
#  'st/NCBI491.h5ad',
#  ...]
